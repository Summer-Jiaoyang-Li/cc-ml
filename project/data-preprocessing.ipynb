# %%
import datetime
import pandas as pd
import os

# %%
cab_data = [
    "yellow_tripdata_2018-01.csv",
    "yellow_tripdata_2018-02.csv",
    "yellow_tripdata_2018-03.csv"
]

# %%
# def get_training_data(raw_data):
#     """
#     input: 
#         raw_data: list of .csv files
    
#     output:
#         list of data useful to training
#         [pickup_time, dropoff_time, trip_distance, PUlocationID, DOlocationID, fare_amt]
    
#     """
#     res = []
#     for file in raw_data:
#         file = os.path.join('data', file)
#         print(file)
#         df = pd.read_csv(file)
#         print(len(df.index))
#         for index, row in df.iterrows():
#             if(index % 10000 == 0):
#                 print(index)
#             res.append({'pickup_time': datetime.datetime.strptime(row['tpep_pickup_datetime'], '%Y-%m-%d %H:%M:%S'),
#                         'dropoff_time': datetime.datetime.strptime(row['tpep_dropoff_datetime'], '%Y-%m-%d %H:%M:%S'),
#                         'trip_distance': int(row['trip_distance']),
#                         'PULocationID': row['PULocationID'],
#                         'DOLocationID': row['DOLocationID'],
#                         'fare_amt': int(row['fare_amount']),
#                         'total_profit': int(row['total_amount'])
#                        })
    
#     return pd.Dataframe(res)

# %%
df = pd.read_csv('data/yellow_tripdata_2018-01.csv')

# %%
print(len(df.index))
# Out:
# 8759874

# %%
datetime.datetime.strptime('2018-01-02 12:30:00', '%Y-%m-%d %H:%M:%S').minute
# Out:
# 30

# %%
df.tpep_pickup_datetime[0][:-3]
# Out:
# '2018-01-01 00:21'

# %%
res = []
for index, row in df.iterrows():
    if(index % 10000 == 0):
        print(index)
    
    pickup_datetime = datetime.datetime.strptime(row['tpep_pickup_datetime'], '%Y-%m-%d %H:%M:%S')
    dropoff_datetime = datetime.datetime.strptime(row['tpep_dropoff_datetime'], '%Y-%m-%d %H:%M:%S')
    
    res.append({'pickup_date' : row['tpep_pickup_datetime'][:-3], 
                'pickup_weekday': pickup_datetime.weekday(),
                'pickup_hour': pickup_datetime.hour,
                'pickup_min': pickup_datetime.minute,
                'trip_distance': float(row['trip_distance']),
                'PULocationID': int(row['PULocationID']),
                'fare_amt': float(row['fare_amount']),
                'total_profit': float(row['total_amount'])
               })
# Out:
# 0
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# 1110000
# 1120000
# 1130000
# 1140000
# 1150000
# 1160000
# 1170000
# 1180000
# 1190000
# 1200000
# 1210000
# 1220000
# 1230000
# 1240000
# 1250000
# 1260000
# 1270000
# 1280000
# 1290000
# 1300000
# 1310000
# 1320000
# 1330000
# 1340000
# 1350000
# 1360000
# 1370000
# 1380000
# 1390000
# 1400000
# 1410000
# 1420000
# 1430000
# 1440000
# 1450000
# 1460000
# 1470000
# 1480000
# 1490000
# 1500000
# 1510000
# 1520000
# 1530000
# 1540000
# 1550000
# 1560000
# 1570000
# 1580000
# 1590000
# 1600000
# 1610000
# 1620000
# 1630000
# 1640000
# 1650000
# 1660000
# 1670000
# 1680000
# 1690000
# 1700000
# 1710000
# 1720000
# 1730000
# 1740000
# 1750000
# 1760000
# 1770000
# 1780000
# 1790000
# 1800000
# 1810000
# 1820000
# 1830000
# 1840000
# 1850000
# 1860000
# 1870000
# 1880000
# 1890000
# 1900000
# 1910000
# 1920000
# 1930000
# 1940000
# 1950000
# 1960000
# 1970000
# 1980000
# 1990000
# 2000000
# 2010000
# 2020000
# 2030000
# 2040000
# 2050000
# 2060000
# 2070000
# 2080000
# 2090000
# 2100000
# 2110000
# 2120000
# 2130000
# 2140000
# 2150000
# 7180000
# 7190000
# 7200000
# 7210000
# 7220000
# 7230000
# 7240000
# 7250000
# 7260000
# 7270000
# 7280000
# 7290000
# 7300000
# 7310000
# 7320000
# 7330000
# 7340000
# 7350000
# 7360000
# 7370000
# 7380000
# 7390000
# 7400000
# 7410000
# 7420000
# 7430000
# 7440000
# 7450000
# 7460000
# 7470000
# 7480000
# 7490000
# 7500000
# 7510000
# 7520000
# 7530000
# 7540000
# 7550000
# 7560000
# 7570000
# 7580000
# 7590000
# 7600000
# 7610000
# 7620000
# 7630000
# 7640000
# 7650000
# 7660000
# 7670000
# 7680000
# 7690000
# 7700000
# 7710000
# 7720000
# 7730000
# 7740000
# 7750000
# 7760000
# 7770000
# 7780000
# 7790000
# 7800000
# 7810000
# 7820000
# 7830000
# 7840000
# 7850000
# 7860000
# 7870000
# 7880000
# 7890000
# 7900000
# 7910000
# 7920000
# 7930000
# 7940000
# 7950000
# 7960000
# 7970000
# 7980000
# 7990000
# 8000000
# 8010000
# 8020000
# 8030000
# 8040000
# 8050000
# 8060000
# 8070000
# 8080000
# 8090000
# 8100000
# 8110000
# 8120000
# 8130000
# 8140000
# 8150000
# 8160000
# 8170000
# 8180000
# 8190000
# 8200000
# 8210000
# 8220000
# 8230000
# 8240000
# 8250000
# 8260000
# 8270000
# 8280000
# 8290000
# 8300000
# 8310000
# 8320000
# 8330000
# 8340000
# 8350000
# 8360000
# 8370000
# 8380000
# 8390000
# 8400000
# 8410000
# 8420000
# 8430000
# 8440000
# 8450000
# 8460000
# 8470000
# 8480000
# 8490000
# 8500000
# 8510000
# 8520000
# 8530000
# 8540000
# 8550000
# 8560000
# 8570000
# 8580000
# 8590000
# 8600000
# 8610000
# 8620000
# 8630000
# 8640000
# 8650000
# 8660000
# 8670000
# 8680000
# 8690000
# 8700000
# 8710000
# 8720000
# 8730000
# 8740000
# 8750000

# %%
df_output = pd.DataFrame(res)

# %%
print(len(df_output.index))
# Out:
# 8759874

# %%
df_output['PULocationID']
# Out:
# 0           41
# 1          239
# 2          262
# 3          140
# 4          246
# 5          143
# 6           50
# 7          239
# 8          238
# 9          170
# 10         162
# 11         141
# 12         137
# 13         224
# 14         234
# 15          13
# 16          48
# 17         163
# 18         229
# 19         236
# 20         263
# 21         239
# 22          90
# 23         233
# 24         161
# 25         234
# 26         234
# 27         142
# 28         170
# 29         233
#           ...
# 8759844    234
# 8759845     68
# 8759846    209
# 8759847    211
# 8759848     43
# 8759849    158
# 8759850    231
# 8759851     90
# 8759852    148
# 8759853    161
# 8759854     88
# 8759855    142
# 8759856    138
# 8759857    230
# 8759858    100
# 8759859    138
# 8759860    186
# 8759861    238
# 8759862    151
# 8759863    238
# 8759864    137
# 8759865    163
# 8759866     43
# 8759867    234
# 8759868    230
# 8759869    158
# 8759870    163
# 8759871     74
# 8759872      7
# 8759873      7
# Name: PULocationID, Length: 8759874, dtype: int64

# %%
print(list(df_output.columns.values))
# Out:
# ['PULocationID', 'fare_amt', 'pickup_date', 'pickup_hour', 'pickup_min', 'pickup_weekday', 'total_profit', 'trip_distance']

# %%
df_reset = df_output.groupby(['pickup_date', 'pickup_hour', 'pickup_min', 'PULocationID', 'pickup_weekday'])['total_profit'].mean().reset_index()

# %%
df_reset2 = df_reset[("2018-01-01 00:00" <= df_reset['pickup_date']) & (df_reset['pickup_date'] < "2018-02-01 00:00")].reset_index()

# %%
df_reset2
# Out:
#            index       pickup_date  pickup_hour  pickup_min  PULocationID  \
# 0            260  2018-01-01 00:00            0           0            13
# 1            261  2018-01-01 00:00            0           0            24
# 2            262  2018-01-01 00:00            0           0            37
# 3            263  2018-01-01 00:00            0           0            43
# 4            264  2018-01-01 00:00            0           0            48
# 5            265  2018-01-01 00:00            0           0            50
# 6            266  2018-01-01 00:00            0           0            61
# 7            267  2018-01-01 00:00            0           0            68
# 8            268  2018-01-01 00:00            0           0            79
# 9            269  2018-01-01 00:00            0           0            90
# 10           270  2018-01-01 00:00            0           0           114
# 11           271  2018-01-01 00:00            0           0           132
# 12           272  2018-01-01 00:00            0           0           138
# 13           273  2018-01-01 00:00            0           0           140
# 14           274  2018-01-01 00:00            0           0           141
# 15           275  2018-01-01 00:00            0           0           142
# 16           276  2018-01-01 00:00            0           0           144
# 17           277  2018-01-01 00:00            0           0           158
# 18           278  2018-01-01 00:00            0           0           161
# 19           279  2018-01-01 00:00            0           0           162
# 20           280  2018-01-01 00:00            0           0           164
# 21           281  2018-01-01 00:00            0           0           166
# 22           282  2018-01-01 00:00            0           0           170
# 23           283  2018-01-01 00:00            0           0           186
# 24           284  2018-01-01 00:00            0           0           229
# 25           285  2018-01-01 00:00            0           0           231
# 26           286  2018-01-01 00:00            0           0           232
# 27           287  2018-01-01 00:00            0           0           233
# 28           288  2018-01-01 00:00            0           0           236
# 29           289  2018-01-01 00:00            0           0           237
# ...          ...               ...          ...         ...           ...
# 2098355  2098615  2018-01-31 23:59           23          59           112
# 2098356  2098616  2018-01-31 23:59           23          59           114
# 2098357  2098617  2018-01-31 23:59           23          59           132
# 2098358  2098618  2018-01-31 23:59           23          59           137
# 2098359  2098619  2018-01-31 23:59           23          59           140
# 2098360  2098620  2018-01-31 23:59           23          59           141
# 2098361  2098621  2018-01-31 23:59           23          59           142
# 2098362  2098622  2018-01-31 23:59           23          59           148
# 2098363  2098623  2018-01-31 23:59           23          59           152
# 2098364  2098624  2018-01-31 23:59           23          59           158
# 2098365  2098625  2018-01-31 23:59           23          59           161
# 2098366  2098626  2018-01-31 23:59           23          59           162
# 2098367  2098627  2018-01-31 23:59           23          59           163
# 2098368  2098628  2018-01-31 23:59           23          59           164
# 2098369  2098629  2018-01-31 23:59           23          59           166
# 2098370  2098630  2018-01-31 23:59           23          59           170
# 2098371  2098631  2018-01-31 23:59           23          59           209
# 2098372  2098632  2018-01-31 23:59           23          59           217
# 2098373  2098633  2018-01-31 23:59           23          59           230
# 2098374  2098634  2018-01-31 23:59           23          59           231
# 2098375  2098635  2018-01-31 23:59           23          59           233
# 2098376  2098636  2018-01-31 23:59           23          59           234
# 2098377  2098637  2018-01-31 23:59           23          59           236
# 2098378  2098638  2018-01-31 23:59           23          59           237
# 2098379  2098639  2018-01-31 23:59           23          59           238
# 2098380  2098640  2018-01-31 23:59           23          59           239
# 2098381  2098641  2018-01-31 23:59           23          59           249
# 2098382  2098642  2018-01-31 23:59           23          59           261
# 2098383  2098643  2018-01-31 23:59           23          59           263
# 2098384  2098644  2018-01-31 23:59           23          59           264
#
#          pickup_weekday  total_profit
# 0                     0      5.760000
# 1                     0     14.800000
# 2                     0     14.800000
# 3                     0     10.140000
# 4                     0     17.920000
# 5                     0     28.300000
# 6                     0     21.800000
# 7                     0      8.058333
# 8                     0     12.550000
# 9                     0     14.160000
# 10                    0      8.300000
# 11                    0     73.200000
# 12                    0     40.300000
# 13                    0     14.760000
# 14                    0      9.300000
# 15                    0     16.550000
# 16                    0      9.100000
# 17                    0     28.950000
# 18                    0     14.466667
# 19                    0     22.616667
# 20                    0     10.575000
# 21                    0      7.560000
# 22                    0     15.330000
# 23                    0      7.050000
# 24                    0     16.212500
# 25                    0     27.800000
# 26                    0      8.300000
# 27                    0      5.800000
# 28                    0      6.050000
# 29                    0     15.550000
# ...                 ...           ...
# 2098355               2     17.800000
# 2098356               2      5.300000
# 2098357               2     72.195000
# 2098358               2     24.375000
# 2098359               2      8.800000
# 2098360               2      7.986667
# 2098361               2     11.800000
# 2098362               2     15.960000
# 2098363               2     18.300000
# 2098364               2     12.338000
# 2098365               2     14.002500
# 2098366               2      8.886667
# 2098367               2      5.800000
# 2098368               2     14.050000
# 2098369               2     12.655000
# 2098370               2     14.493333
# 2098371               2     11.300000
# 2098372               2      5.300000
# 2098373               2     21.847143
# 2098374               2     18.650000
# 2098375               2     20.800000
# 2098376               2     15.244286
# 2098377               2      6.300000
# 2098378               2     10.300000
# 2098379               2      9.450000
# 2098380               2     11.960000
# 2098381               2      6.350000
# 2098382               2     45.805000
# 2098383               2      7.250000
# 2098384               2      9.100000
#
# [2098385 rows x 7 columns]

# %%
df_output.to_pickle('processed_data.pkl')

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
import numpy

# %%
X = df_output.as_matrix(columns=['pickup_weekday', 'pickup_hour', 'pickup_min','PULocationID'])
y = df_output.as_matrix(columns=['total_profit']).ravel()
# Out:
# /Users/jiaoyangli/venv/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# /Users/jiaoyangli/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
model = RandomForestRegressor(n_estimators=20, verbose=2)
model.fit(X_train, y_train)
# Out:
# building tree 1 of 20
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   17.6s remaining:    0.0s
# building tree 2 of 20
# building tree 3 of 20
# building tree 4 of 20
# building tree 5 of 20
# building tree 6 of 20
# building tree 7 of 20
# building tree 8 of 20
# building tree 9 of 20
# building tree 10 of 20
# building tree 11 of 20
# building tree 12 of 20
# building tree 13 of 20
# building tree 14 of 20
# building tree 15 of 20
# building tree 16 of 20
# building tree 17 of 20
# building tree 18 of 20
# building tree 19 of 20
# building tree 20 of 20
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:  5.9min finished
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=20, n_jobs=1, oob_score=False, random_state=None,
#            verbose=2, warm_start=False)

# %%
r_square = model.score(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   58.4s finished

# %%
r_square
# Out:
# 0.34874310386118135

# %%
r_test = model.score(X_test, y_test)
# Out:
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:   47.6s finished

# %%
r_test
# Out:
# 0.3538654539472964

# %%
model = SVR(C=1.0, epsilon=0.1, verbose=True)
model.fit(X_train[:10], y_train[:10])

# %%
r_square = model.score(X_train, y_train)

# %%
r_square

# %%
r_test = model.score(X_test, y_test)

# %%
r_test
